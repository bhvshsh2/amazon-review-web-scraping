# %%
from bs4 import BeautifulSoup
import urllib.error,urllib.parse,urllib.request


url='https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B07X8V5YKR/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2'

html=urllib.request.urlopen(url)

# %%
soup=BeautifulSoup(html)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <link href="//images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="//images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# var iUrl = "https://images-eu.ssl-images-amazon.com/images/I/41kdXh6O3rL._SY300_QL70_ML2_.jpg";
# (function(){var i=new Image; i.src = iUrl;})();
# </script>
# <!-- NAVYAAN CSS -->
# <link href="https://images-eu.ssl-images-amazon.com/images/I/21jnApV8bZL._RC|71o4HGxm3sL.css,21TJB5pc5TL.css,31ObJNiVywL.css,21lRUdwotiL.css,41TCfXduFuL.css,11G4HxMtMSL.css,31OvHRW+XiL.css,01XHMOHpK1L.css_.css?AUIClients/NavDesktopUberAsset#desktop.in" rel="stylesheet"/>
# ...

# %%
review_title=soup.findAll("a",{'data-hook':"review-title"})

# %%
review_title
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R15AKE4BJCQ8UZ?ASIN=B07X8V5YKR">
#  <span>Save yourself, and don't fall for paid YouTube reviews</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R1PR39UWAIMOOJ?ASIN=B07X8V5YKR">
#  <span>Not a value for money product</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R2UUJEVZ4SCU2J?ASIN=B07X8V5YKR">
#  <span>Fingerprint sensor doesn't work.</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3JHX7A10WPXMQ?ASIN=B07X8V5YKR">
#  <span>Not Lite in features</span>
#  </a>,
# ...

# %%
title = []
for i in range(0,len(review_title)):
    title.append(review_title[i].get_text())
title
# Out:
# ["\nSave yourself, and don't fall for paid YouTube reviews\n",
#  '\nNot a value for money product\n',
#  "\nFingerprint sensor doesn't work.\n",
#  '\nNot Lite in features\n',
#  '\nUnable to meet my expectations\n',
#  '\nHeating issue and battery life\n',
#  '\nGood\n',
#  '\nAll Main Pros and Cons\n']

# %%
title[:] = [titles.lstrip('\n') for titles in title] and [titles.rstrip('\n') for titles in title]

# %%
title
# Out:
# ["Save yourself, and don't fall for paid YouTube reviews",
#  'Not a value for money product',
#  "Fingerprint sensor doesn't work.",
#  'Not Lite in features',
#  'Unable to meet my expectations',
#  'Heating issue and battery life',
#  'Good',
#  'All Main Pros and Cons']

# %%
name=soup.find_all("span",{"class":"a-profile-name"})

# %%
name
# Out:
# [<span class="a-profile-name">Arijit Sinharoy</span>,
#  <span class="a-profile-name">Anil Meena</span>,
#  <span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">Subhas</span>,
#  <span class="a-profile-name">Kaushal Kumar</span>,
#  <span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">Sri Raghava</span>,
#  <span class="a-profile-name">Amazon Customer</span>]

# %%
cust_names=[]
for i in range(0,len(name)):
    cust_names.append(name[i].get_text())
cust_names
# Out:
# ['Arijit Sinharoy',
#  'Anil Meena',
#  'Amazon Customer',
#  'Subhas',
#  'Kaushal Kumar',
#  'Amazon Customer',
#  'Sri Raghava',
#  'Amazon Customer']

# %%
rating=soup.find_all("i",{"data-hook":"review-star-rating"})

# %%
rating
# Out:
# [<i class="a-icon a-icon-star a-star-1 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">1.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-3 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">3.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-3 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">3.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-3 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">3.0 out of 5 stars</span></i>,
# ...

# %%
ratings=[]
for i in range(0,len(rating)):
    ratings.append(rating[i].get_text())
ratings
# Out:
# ['1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
review=soup.find_all("div",{"data-hook":"review-collapsed"})

# %%
review
# Out:
# [<div aria-expanded="false" class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content" data-hook="review-collapsed">
#  <span>Please don't buy this untill and unless you really really REALLY want a S pen. Very bad quality front camera, clicks like a 7k phone. Selfies are all soft and smudgy however the back camera is superb. Then the fingerprint scanner, that's a different story all together. Started to fail every single time after 2days of purchasing. Dual sim Never works as when both of sim cards are at play, this phone struggles real hard to provide you network. Overall a very avarage phone, and surely overpriced. This phone should have costed 22k max....</span>
#  </div>,
#  <div aria-expanded="false" class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content" data-hook="review-collapsed">
# ...

# %%
reviews=[]
for i in range(0,len(review)):
    reviews.append(review[i].get_text())
reviews
# Out:
# ["\nPlease don't buy this untill and unless you really really REALLY want a S pen. Very bad quality front camera, clicks like a 7k phone. Selfies are all soft and smudgy however the back camera is superb. Then the fingerprint scanner, that's a different story all together. Started to fail every single time after 2days of purchasing. Dual sim Never works as when both of sim cards are at play, this phone struggles real hard to provide you network. Overall a very avarage phone, and surely overpriced. This phone should have costed 22k max....\n",
#  '\nPhone is overpriced as build quality, the display quality is not good as 40k phone, really disappointed, my first bad experience with Samsung.\n',
# ...

# %%
reviews[:]=[review.lstrip('\n') for review in reviews] #and [review.rstrip('\n') for review in reviews]
reviews
# Out:
# ["Please don't buy this untill and unless you really really REALLY want a S pen. Very bad quality front camera, clicks like a 7k phone. Selfies are all soft and smudgy however the back camera is superb. Then the fingerprint scanner, that's a different story all together. Started to fail every single time after 2days of purchasing. Dual sim Never works as when both of sim cards are at play, this phone struggles real hard to provide you network. Overall a very avarage phone, and surely overpriced. This phone should have costed 22k max....",
#  'Phone is overpriced as build quality, the display quality is not good as 40k phone, really disappointed, my first bad experience with Samsung.',
# ...

# %%
title
# Out:
# ["Save yourself, and don't fall for paid YouTube reviews",
#  'Not a value for money product',
#  "Fingerprint sensor doesn't work.",
#  'Not Lite in features',
#  'Unable to meet my expectations',
#  'Heating issue and battery life',
#  'Good',
#  'All Main Pros and Cons']

# %%
cust_names
# Out:
# ['Arijit Sinharoy',
#  'Anil Meena',
#  'Amazon Customer',
#  'Subhas',
#  'Kaushal Kumar',
#  'Amazon Customer',
#  'Sri Raghava',
#  'Amazon Customer']

# %%
ratings
# Out:
# ['1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
reviews
# Out:
# ["Please don't buy this untill and unless you really really REALLY want a S pen. Very bad quality front camera, clicks like a 7k phone. Selfies are all soft and smudgy however the back camera is superb. Then the fingerprint scanner, that's a different story all together. Started to fail every single time after 2days of purchasing. Dual sim Never works as when both of sim cards are at play, this phone struggles real hard to provide you network. Overall a very avarage phone, and surely overpriced. This phone should have costed 22k max....",
#  'Phone is overpriced as build quality, the display quality is not good as 40k phone, really disappointed, my first bad experience with Samsung.',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df['Customer Name']=cust_names
df
# Out:
#      Customer Name
# 0  Arijit Sinharoy
# 1       Anil Meena
# 2  Amazon Customer
# 3           Subhas
# 4    Kaushal Kumar
# 5  Amazon Customer
# 6      Sri Raghava
# 7  Amazon Customer

# %%
df['Rating']=ratings
df
# Out:
#      Customer Name              Rating
# 0  Arijit Sinharoy  1.0 out of 5 stars
# 1       Anil Meena  3.0 out of 5 stars
# 2  Amazon Customer  4.0 out of 5 stars
# 3           Subhas  5.0 out of 5 stars
# 4    Kaushal Kumar  3.0 out of 5 stars
# 5  Amazon Customer  3.0 out of 5 stars
# 6      Sri Raghava  5.0 out of 5 stars
# 7  Amazon Customer  4.0 out of 5 stars

# %%
df['Review Title']=title
df
# Out:
#      Customer Name              Rating  \
# 0  Arijit Sinharoy  1.0 out of 5 stars
# 1       Anil Meena  3.0 out of 5 stars
# 2  Amazon Customer  4.0 out of 5 stars
# 3           Subhas  5.0 out of 5 stars
# 4    Kaushal Kumar  3.0 out of 5 stars
# 5  Amazon Customer  3.0 out of 5 stars
# 6      Sri Raghava  5.0 out of 5 stars
# 7  Amazon Customer  4.0 out of 5 stars
#
#                                         Review Title
# 0  Save yourself, and don't fall for paid YouTube...
# 1                      Not a value for money product
# 2                   Fingerprint sensor doesn't work.
# 3                               Not Lite in features
# 4                     Unable to meet my expectations
# 5                     Heating issue and battery life
# 6                                               Good
# 7                             All Main Pros and Cons

# %%
df['Reviews']=reviews
df
# Out:
#      Customer Name              Rating  \
# 0  Arijit Sinharoy  1.0 out of 5 stars
# 1       Anil Meena  3.0 out of 5 stars
# 2  Amazon Customer  4.0 out of 5 stars
# 3           Subhas  5.0 out of 5 stars
# 4    Kaushal Kumar  3.0 out of 5 stars
# 5  Amazon Customer  3.0 out of 5 stars
# 6      Sri Raghava  5.0 out of 5 stars
# 7  Amazon Customer  4.0 out of 5 stars
#
#                                         Review Title  \
# 0  Save yourself, and don't fall for paid YouTube...
# 1                      Not a value for money product
# 2                   Fingerprint sensor doesn't work.
# 3                               Not Lite in features
# 4                     Unable to meet my expectations
# 5                     Heating issue and battery life
# 6                                               Good
# 7                             All Main Pros and Cons
#
#                                              Reviews
# 0  Please don't buy this untill and unless you re...
# ...

# %%
df.to_csv(r'E:\web-scraping_Amazon-reviews.csv',index=True)

# %%
#review scraping from amazon
from bs4 import BeautifulSoup
import urllib.error,urllib.parse,urllib.request

def pdreview(url):
    #url='https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/dp/B07X8V5YKR/ref=sr_1_1_sspa?dchild=1&fst=as%3Aoff&qid=1590381876&rnid=21021782031&s=electronics&sr=1-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUFHRklTOU5KWkRVWjMmZW5jcnlwdGVkSWQ9QTAwNTY3OTMzMkE1TUJWSlNJOFMmZW5jcnlwdGVkQWRJZD1BMDE4Mjc0NFVXUURHSVlDRUU1USZ3aWRnZXROYW1lPXNwX2F0Zl9icm93c2UmYWN0aW9uPWNsaWNrUmVkaXJlY3QmZG9Ob3RMb2dDbGljaz10cnVl'

    html=urllib.request.urlopen(url)

    soup=BeautifulSoup(html)
    review_title=soup.findAll("a",{'data-hook':"review-title"})
    title = []
    for i in range(0,len(review_title)):
        title.append(review_title[i].get_text())

    name=soup.find_all("span",{"class":"a-profile-name"})
    cust_names=[]
    for i in range(0,len(name)):
        cust_names.append(name[i].get_text())
    rating=soup.find_all("i",{"data-hook":"review-star-rating"})
    ratings=[]
    for i in range(0,len(rating)):
        ratings.append(rating[i].get_text())
    review=soup.find_all("div",{"data-hook":"review-collapsed"})

    reviews=[]
    for i in range(0,len(review)):
        reviews.append(review[i].get_text())

    reviews[:]=[review.lstrip('\n') for review in reviews]

    import pandas as pd
    df = pd.DataFrame()
    df['Customer Name']=cust_names
    df['Rating']=ratings
    df['Review Title']=title
    df['Reviews']=reviews
pdreview('https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/dp/B07X8V5YKR/ref=sr_1_1_sspa?dchild=1&fst=as%3Aoff&qid=1590381876&rnid=21021782031&s=electronics&sr=1-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUFHRklTOU5KWkRVWjMmZW5jcnlwdGVkSWQ9QTAwNTY3OTMzMkE1TUJWSlNJOFMmZW5jcnlwdGVkQWRJZD1BMDE4Mjc0NFVXUURHSVlDRUU1USZ3aWRnZXROYW1lPXNwX2F0Zl9icm93c2UmYWN0aW9uPWNsaWNrUmVkaXJlY3QmZG9Ob3RMb2dDbGljaz10cnVl')

def visual(cust_names,ratings,title,reviews):
    import pandas as pd
    df = pd.DataFrame()
    df['Customer Names']=cust_names
    df['Ratings']=ratings
    df['Review Titles']=title
    df['Reviewss']=reviews
    
    
df
# Out:
#     Customer Names             Ratings  \
# 0  Arijit Sinharoy  1.0 out of 5 stars
# 1       Anil Meena  3.0 out of 5 stars
# 2  Amazon Customer  4.0 out of 5 stars
# 3           Subhas  5.0 out of 5 stars
# 4    Kaushal Kumar  3.0 out of 5 stars
# 5  Amazon Customer  3.0 out of 5 stars
# 6      Sri Raghava  5.0 out of 5 stars
# 7           piyush  5.0 out of 5 stars
#
#                                        Review Titles  \
# 0  \nSave yourself, and don't fall for paid YouTu...
# 1                  \nNot a value for money product\n
# 2               \nFingerprint sensor doesn't work.\n
# 3                           \nNot Lite in features\n
# 4                 \nUnable to meet my expectations\n
# 5                 \nHeating issue and battery life\n
# 6                                           \nGood\n
# 7  \nGreat Value for Money for someone looking fo...
#
#                                             Reviewss
# 0  Please don't buy this untill and unless you re...
# ...

# %%
#refrigerator specification scraping from amazon
url='https://www.amazon.in/b/ref=s9_acsd_al_bw_clnk/ref=s9_acsd_al_bw_c2_x_c2cl?node=20348110031&pf_rd_m=A1K21FY43GMZF8&pf_rd_s=merchandised-search-5&pf_rd_r=PP485ZA11E00XEPQ9GE3&pf_rd_t=101&pf_rd_p=e0188f6e-cbe0-43c7-b9a8-44a2558f9568&pf_rd_i=21488087031'

# %%
from bs4 import BeautifulSoup
import urllib.error,urllib.parse,urllib.request

#def pdreview(url):
    #url='https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/dp/B07X8V5YKR/ref=sr_1_1_sspa?dchild=1&fst=as%3Aoff&qid=1590381876&rnid=21021782031&s=electronics&sr=1-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUFHRklTOU5KWkRVWjMmZW5jcnlwdGVkSWQ9QTAwNTY3OTMzMkE1TUJWSlNJOFMmZW5jcnlwdGVkQWRJZD1BMDE4Mjc0NFVXUURHSVlDRUU1USZ3aWRnZXROYW1lPXNwX2F0Zl9icm93c2UmYWN0aW9uPWNsaWNrUmVkaXJlY3QmZG9Ob3RMb2dDbGljaz10cnVl'
url='https://www.amazon.in/stores/page/0B6D4C19-FD81-40F5-B02B-6E6026BA3D8F?store_ref=SB_A04010842HG8YPKXM17ZR&pf_rd_p=b4cc5800-8875-4c20-b1bd-0f22edd01388&aaxitk=OQb8QkORaSc7LDVBtpnqvQ&hsa_cr_id=9302380860702&lp_asins=B083KQFY62,B083KW4D6D,B083KRNF9T&lp_mat_key=fridges&lp_query=fridge&lp_slot=auto-sparkle-hsa-tetris&ref_=sb_s_sparkle'    
html=urllib.request.urlopen(url)

soup=BeautifulSoup(html)

#name=soup.findall("span",{"class":"a-truncate-cut"})

# %%
name=soup.find_all("div",{"class":"style__item__3gM_7"})

# %%
#pdname=[]
#for i in range(0,len(name)):
 #   pdname.append(name[i].get_text())
#pdname
name
# Out:
# []

# %%
#name
# Out:
# [<span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
#  <span aria-hidden="true" class="a-truncate-cut a-hidden"></span>,
# ...

# %%
def f(n):
    return n // 2 if n % 2 == 0 else 3*n + 1


print(f(f(f(f(f(f(f(f(f(f(f(f(f(f(1071)))))))))))))))
# Out:
# 3053
